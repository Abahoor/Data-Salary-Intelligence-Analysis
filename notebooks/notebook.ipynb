# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


pd.set_option("display.max_columns", None)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# # =====================================================
# # Project: Salary Data Cleaning & Analysis
# # Author: Abahoor Lion
# # Goal:
# # Combine multiple salary datasets, clean the data,
# # merge into one master dataset, analyze it using SQL,
# # and build an interactive Power BI dashboard.
# # =====================================================

# %% [markdown]
# # Project Notes
#
# ## Dataset_2
#
# salary_currency: The currency in which the salary is paid, such as USD, EUR, etc. This is important for currency conversion and understanding the actual value of the salary in a global context.
#
# salary: The annual gross salary of the role in the local currency. This raw salary figure is key for direct regional salary comparisons.
#
# salary_in_usd: The annual gross salary converted to United States Dollars (USD). This uniform currency conversion aids in global salary comparisons and analyses.
#
# ## Dataset_3
#
# experience_level: The experience level in the job during the year (EN: Entry-level/Junior, MI: Mid-level/Intermediate, SE: Senior-level/Expert, EX: Executive-level/Director).
#
# employment_type: The type of employment for the role (PT: Part-time, FT: Full-time, CT: Contract, FL: Freelance).
#
# salary: The total gross salary amount paid.
# salary_currency: The currency of the salary paid as an ISO 4217 currency code.
# salary_in_usd: The salary in USD (FX rate divided by avg. USD rate of respective year).
#
# remote_ratio: The overall amount of work done remotely (0: No remote work, 50: Partially remote/hybrid, 100: Fully remote).
#
# company_size: The average number of people that worked for the company during the year (S: less than 50 employees, M: 50 to 250 employees, L: more than 250 employees).

# %%
df_1=pd.read_csv("../data/raw/DataAnalyst_set1_raw.csv")
df_1.head(10)
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
# 5           5                                       Data Analyst
# 6           6                       Business/Data Analyst (FP&A)
# 7           7                               Data Science Analyst
# 8           8                                       Data Analyst
# 9           9                      Data Analyst, Merchant Health
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
# 5  $37K-$66K (Glassdoor est.)
# 6  $37K-$66K (Glassdoor est.)
# 7  $37K-$66K (Glassdoor est.)
# 8  $37K-$66K (Glassdoor est.)
# 9  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# 5  About Cubist\nCubist Systematic Strategies is ...     3.9
# 6  Two Sigma is a different kind of investment ma...     4.4
# 7  Data Science Analyst\n\nJob Details\nLevel\nEx...     3.7
# 8  The Data Analyst is an integral member of the ...     4.0
# 9  About Us\n\nRiskified is the AI platform power...     4.4
#
#                               Company Name      Location  \
# 0           Vera Institute of Justice\n3.2  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY
# 2                         Squarespace\n3.4  New York, NY
# 3                            Celerity\n4.1  New York, NY
# 4                             FanDuel\n3.9  New York, NY
# 5                             Point72\n3.9  New York, NY
# 6                           Two Sigma\n4.4  New York, NY
# 7             GNY Insurance Companies\n3.7  New York, NY
# 8                                DMGT\n4.0  New York, NY
# 9                           Riskified\n4.4  New York, NY
#
#              Headquarters                     Size  Founded  \
# 0            New York, NY     201 to 500 employees     1961
# 1            New York, NY         10000+ employees     1893
# 2            New York, NY   1001 to 5000 employees     2003
# 3              McLean, VA     201 to 500 employees     2002
# 4            New York, NY    501 to 1000 employees     2009
# 5            Stamford, CT   1001 to 5000 employees     2014
# 6            New York, NY   1001 to 5000 employees     2001
# 7            New York, NY     201 to 500 employees     1914
# 8  London, United Kingdom  5001 to 10000 employees     1896
# 9            New York, NY    501 to 1000 employees     2013
#
#                 Type of ownership                               Industry  \
# 0          Nonprofit Organization                      Social Assistance
# 1          Nonprofit Organization       Health Care Services & Hospitals
# 2               Company - Private                               Internet
# 3  Subsidiary or Business Segment                            IT Services
# 4               Company - Private                    Sports & Recreation
# 5               Company - Private  Investment Banking & Asset Management
# 6               Company - Private  Investment Banking & Asset Management
# 7               Company - Private                     Insurance Carriers
# 8                Company - Public       Venture Capital & Private Equity
# 9               Company - Private                 Research & Development
#
#                              Sector                     Revenue  \
# 0                        Non-Profit  $100 to $500 million (USD)
# 1                       Health Care      $2 to $5 billion (USD)
# 2            Information Technology    Unknown / Non-Applicable
# 3            Information Technology   $50 to $100 million (USD)
# 4  Arts, Entertainment & Recreation  $100 to $500 million (USD)
# 5                           Finance    Unknown / Non-Applicable
# 6                           Finance    Unknown / Non-Applicable
# 7                         Insurance  $100 to $500 million (USD)
# 8                           Finance      $1 to $2 billion (USD)
# 9                 Business Services    Unknown / Non-Applicable
#
#                         Competitors Easy Apply
# 0                                -1       True
# 1                                -1         -1
# 2                           GoDaddy         -1
# 3                                -1         -1
# 4                        DraftKings       True
# 5                                -1         -1
# 6                                -1         -1
# 7  Travelers, Chubb, Crum & Forster       True
# 8  Thomson Reuters, Hearst, Pearson         -1
# 9                  Signifyd, Forter         -1

# %%
df_1.isnull().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         1
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
df_2=pd.read_csv("../data/raw/jobs_in_data_set2_raw.csv")
df_2.head(10)
# Out:
#    work_year                    job_title                    job_category  \
# 0       2023         Data DevOps Engineer                Data Engineering
# 1       2023               Data Architect  Data Architecture and Modeling
# 2       2023               Data Architect  Data Architecture and Modeling
# 3       2023               Data Scientist       Data Science and Research
# 4       2023               Data Scientist       Data Science and Research
# 5       2023               Data Scientist       Data Science and Research
# 6       2023               Data Scientist       Data Science and Research
# 7       2023  Machine Learning Researcher         Machine Learning and AI
# 8       2023  Machine Learning Researcher         Machine Learning and AI
# 9       2023                Data Engineer                Data Engineering
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
# 5             USD  130000         130000      United States           Senior
# 6             USD  100000         100000      United States           Senior
# 7             USD  224400         224400      United States        Mid-level
# 8             USD  138700         138700      United States        Mid-level
# 9             USD  210000         210000      United States        Executive
#
#   employment_type work_setting company_location company_size
# 0       Full-time       Hybrid          Germany            L
# 1       Full-time    In-person    United States            M
# 2       Full-time    In-person    United States            M
# 3       Full-time    In-person    United States            M
# 4       Full-time    In-person    United States            M
# 5       Full-time       Remote    United States            M
# 6       Full-time       Remote    United States            M
# 7       Full-time    In-person    United States            M
# 8       Full-time    In-person    United States            M
# 9       Full-time       Remote    United States            M

# %%
df_2.isnull().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df_3=pd.read_csv("../data/raw/global_ai_ml_data_salaries_set3_raw.csv")
df_3.head(10)
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT             Data Architect
# 1       2024               SE              FT             Data Architect
# 2       2024               MI              FT            Insight Analyst
# 3       2024               MI              FT            Insight Analyst
# 4       2024               SE              FT              Lead Engineer
# 5       2024               SE              FT              Lead Engineer
# 6       2024               SE              FT  Machine Learning Engineer
# 7       2024               SE              FT  Machine Learning Engineer
# 8       2024               SE              FT  Machine Learning Engineer
# 9       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  170955             USD         170955                 US             0
# 1  130270             USD         130270                 US             0
# 2   92144             USD          92144                 US           100
# 3   57616             USD          57616                 US           100
# 4  201600             USD         201600                 US           100
# 5  181440             USD         181440                 US           100
# 6  296300             USD         296300                 US             0
# 7  166600             USD         166600                 US             0
# 8  264200             USD         264200                 US             0
# 9  143100             USD         143100                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            M
# 4               US            M
# 5               US            M
# 6               US            M
# 7               US            M
# 8               US            M
# 9               US            M

# %%
df_3.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
print(df_1.shape)
print("---------------")
print(df_1.info())
# Out:
# (2253, 16)
# ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 281.8+ KB
# None

# %%
print(df_2.shape)
print("--------")
print(df_2.info())
# Out:
# (9355, 12)
# --------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB
# None

# %%
print(df_3.shape)
print("-----------")
print(df_3.info())
print("--------------")
print(df_3.describe())
# Out:
# (40332, 11)
# -----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40332 entries, 0 to 40331
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           40332 non-null  int64
#  1   experience_level    40332 non-null  object
#  2   employment_type     40332 non-null  object
#  3   job_title           40332 non-null  object
#  4   salary              40332 non-null  int64
#  5   salary_currency     40332 non-null  object
#  6   salary_in_usd       40332 non-null  int64
#  7   employee_residence  40332 non-null  object
#  8   remote_ratio        40332 non-null  int64
#  9   company_location    40332 non-null  object
#  10  company_size        40332 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 3.4+ MB
# None
# --------------
#           work_year        salary  salary_in_usd  remote_ratio
# count  40332.000000  4.033200e+04   40332.000000  40332.000000
# mean    2023.682832  1.667671e+05  160758.519637     22.570168
# std        0.594596  2.281992e+05   72773.970396     41.611669
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.100000e+05  110000.000000      0.000000
# 50%     2024.000000  1.500000e+05  150000.000000      0.000000
# 75%     2024.000000  2.000000e+05  200000.000000      0.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %%
print(df_1.duplicated().sum())
print(df_2.duplicated().sum())
print(df_3.duplicated().sum())
# Out:
# 0
# 4014
# 19925

# %%
df_1.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Rating', 'Company Name', 'Location',
#        'Headquarters', 'Size', 'Founded', 'Type of ownership', 'Industry',
#        'Sector', 'Revenue', 'Competitors', 'Easy Apply'],
#       dtype='object')

# %%
df_2.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %%
df_3.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df_1.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df_1.drop(columns=["Job Description"],inplace=True)

# %%
df_1["Easy Apply"].value_counts(dropna=False)
# Out:
# Easy Apply
# -1      2173
# True      80
# Name: count, dtype: int64

# %%
df_1["Competitors"].value_counts(dropna=False)
# Out:
# Competitors
# -1                                                           1732
# Adecco, Manpower                                               14
# Robert Half, Insight Global                                    14
# Google, Microsoft, Samsung Electronics                         10
# Artech Information Systems, Mindlance, Tech Mahindra           10
#                                                              ...
# Cognizant Technology Solutions, Infosys, HCL Technologies       1
# Equinix, Digital Realty, CyrusOne                               1
# WeDo technologies, Intec Telecom, Amdocs                        1
# Thomson Reuters, Hearst, Pearson                                1
# Travelers, Chubb, Crum & Forster                                1
# Name: count, Length: 291, dtype: int64

# %%
df_1["Easy Apply"].unique
# Out:
# <bound method Series.unique of 0       True
# 1         -1
# 2         -1
# 3         -1
# 4       True
#         ...
# 2248      -1
# 2249      -1
# 2250      -1
# 2251      -1
# 2252      -1
# Name: Easy Apply, Length: 2253, dtype: object>

# %%
#Every val is stored as str
#Look at the typ of the value beffor changing it
df_1["Easy Apply"].apply(type).value_counts()
# Out:
# Easy Apply
# <class 'str'>    2253
# Name: count, dtype: int64

# %%
df_1["Easy Apply"]=df_1["Easy Apply"].replace({"True": 1 , "-1": 0})
# Out:
# C:\Users\abaho\AppData\Local\Temp\ipykernel_6392\1468928158.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_1["Easy Apply"]=df_1["Easy Apply"].replace({"True": 1 , "-1": 0})

# %%
df_1["Easy Apply"].value_counts(dropna=False)
# Out:
# Easy Apply
# 0    2173
# 1      80
# Name: count, dtype: int64

# %%
df_1["Easy Apply"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Data Cleaning Step 1: Easy Apply
#
# **Issue:**
# The `Easy Apply` column contained `True` and `-1`, which are not ideal for SQL or Power BI.
#
# **Solution:**
# Converted:
# - `True` → `1`
# - `-1` → `0`
#
# **Reason:**
# A binary (0/1) column is easier to analyze, filter, and aggregate in SQL and Power BI.

# %%
df_1["Salary Estimate"].head(10)
# Out:
# 0    $37K-$66K (Glassdoor est.)
# 1    $37K-$66K (Glassdoor est.)
# 2    $37K-$66K (Glassdoor est.)
# 3    $37K-$66K (Glassdoor est.)
# 4    $37K-$66K (Glassdoor est.)
# 5    $37K-$66K (Glassdoor est.)
# 6    $37K-$66K (Glassdoor est.)
# 7    $37K-$66K (Glassdoor est.)
# 8    $37K-$66K (Glassdoor est.)
# 9    $37K-$66K (Glassdoor est.)
# Name: Salary Estimate, dtype: object

# %%
df_1["Salary Estimate"].tail(10)
#The values are sorted
# Out:
# 2243    $78K-$104K (Glassdoor est.)
# 2244    $78K-$104K (Glassdoor est.)
# 2245    $78K-$104K (Glassdoor est.)
# 2246    $78K-$104K (Glassdoor est.)
# 2247    $78K-$104K (Glassdoor est.)
# 2248    $78K-$104K (Glassdoor est.)
# 2249    $78K-$104K (Glassdoor est.)
# 2250    $78K-$104K (Glassdoor est.)
# 2251    $78K-$104K (Glassdoor est.)
# 2252    $78K-$104K (Glassdoor est.)
# Name: Salary Estimate, dtype: object

# %%
# Use value_counts to see the most commend values.
# Use head() function to see the most common value and tail() for the least common value 
df_1["Salary Estimate"].value_counts().head(10)
# Out:
# Salary Estimate
# $41K-$78K (Glassdoor est.)     57
# $42K-$76K (Glassdoor est.)     57
# $50K-$86K (Glassdoor est.)     41
# $35K-$67K (Glassdoor est.)     33
# $60K-$124K (Glassdoor est.)    31
# $58K-$93K (Glassdoor est.)     31
# $43K-$76K (Glassdoor est.)     31
# $46K-$87K (Glassdoor est.)     30
# $51K-$87K (Glassdoor est.)     30
# $37K-$66K (Glassdoor est.)     30
# Name: count, dtype: int64

# %%
df_1["Salary Estimate"].value_counts().tail(10)
# Out:
# Salary Estimate
# $40K-$74K (Glassdoor est.)    9
# $30K-$54K (Glassdoor est.)    8
# $42K-$63K (Glassdoor est.)    4
# $31K-$59K (Glassdoor est.)    4
# $32K-$56K (Glassdoor est.)    4
# $47K-$81K (Glassdoor est.)    3
# $36K-$67K (Glassdoor est.)    3
# $43K-$77K (Glassdoor est.)    3
# $57K-$70K (Glassdoor est.)    2
# -1                            1
# Name: count, dtype: int64

# %%
df_1[df_1["Salary Estimate"] == "-1"]
# Out:
#       Unnamed: 0                                  Job Title Salary Estimate  \
# 2149        2149  Configuration/Data Management Analyst III              -1
#
#                                         Job Description  Rating  \
# 2149  Job Description\nPosition Title: Configuration...     4.4
#
#          Company Name  Location  Headquarters                 Size  Founded  \
# 2149  Protingent\n4.4  Kent, WA  Bellevue, WA  51 to 200 employees     2001
#
#       Type of ownership                Industry             Sector  \
# 2149  Company - Private  Staffing & Outsourcing  Business Services
#
#                        Revenue Competitors Easy Apply
# 2149  $25 to $50 million (USD)          -1         -1

# %%
df_1["Salary Estimate"].sample(20,random_state=42)
# Out:
# 1785     $28K-$52K (Glassdoor est.)
# 1263    $76K-$122K (Glassdoor est.)
# 2126    $55K-$101K (Glassdoor est.)
# 599     $57K-$103K (Glassdoor est.)
# 464      $43K-$69K (Glassdoor est.)
# 1264    $76K-$122K (Glassdoor est.)
# 1745     $50K-$86K (Glassdoor est.)
# 1960    $93K-$159K (Glassdoor est.)
# 1566     $51K-$93K (Glassdoor est.)
# 1270    $76K-$122K (Glassdoor est.)
# 134      $59K-$85K (Glassdoor est.)
# 613      $35K-$45K (Glassdoor est.)
# 188     $60K-$110K (Glassdoor est.)
# 1317     $24K-$48K (Glassdoor est.)
# 1928    $99K-$178K (Glassdoor est.)
# 1985    $82K-$116K (Glassdoor est.)
# 2094     $34K-$61K (Glassdoor est.)
# 445      $26K-$47K (Glassdoor est.)
# 410      $48K-$96K (Glassdoor est.)
# 1061     $45K-$78K (Glassdoor est.)
# Name: Salary Estimate, dtype: object

# %%
df_1["salary_clean"] = df_1["Salary Estimate"]

# %%
df_1["Salary Estimate"] = df_1["Salary Estimate"].str.replace("(Glassdoor est.)","")
print(df_1["Salary Estimate"] )
# Out:
# 0        37-66
# 1        37-66
# 2        37-66
# 3        37-66
# 4        37-66
#          ...
# 2248    78-104
# 2249    78-104
# 2250    78-104
# 2251    78-104
# 2252    78-104
# Name: Salary Estimate, Length: 2253, dtype: object

# %%
df_1["Salary Estimate"].head()
# Out:
# 0    37-66
# 1    37-66
# 2    37-66
# 3    37-66
# 4    37-66
# Name: Salary Estimate, dtype: object

# %%
df_1["Salary Estimate"]=df_1["Salary Estimate"].str.replace("$","")

# %%
df_1["Salary Estimate"] =df_1["Salary Estimate"] .str.replace("K","")
print(df_1["Salary Estimate"] )
# Out:
# 0        37-66
# 1        37-66
# 2        37-66
# 3        37-66
# 4        37-66
#          ...
# 2248    78-104
# 2249    78-104
# 2250    78-104
# 2251    78-104
# 2252    78-104
# Name: Salary Estimate, Length: 2253, dtype: object

# %%
# Creat two colum out of one colum
df_1[["salary_min","salary_max"]] = df_1["Salary Estimate"].str.split("-",expand=True)

# %%
df_1["salary_min"]
# Out:
# 0       37
# 1       37
# 2       37
# 3       37
# 4       37
#         ..
# 2248    78
# 2249    78
# 2250    78
# 2251    78
# 2252    78
# Name: salary_min, Length: 2253, dtype: object

# %%
df_1[["Salary Estimate", "salary_min", "salary_max"]].head()
# Out:
#   Salary Estimate salary_min salary_max
# 0          37-66          37        66
# 1          37-66          37        66
# 2          37-66          37        66
# 3          37-66          37        66
# 4          37-66          37        66

# %%
df_1["salary_min"].apply(type)
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
#             ...
# 2248    <class 'str'>
# 2249    <class 'str'>
# 2250    <class 'str'>
# 2251    <class 'str'>
# 2252    <class 'str'>
# Name: salary_min, Length: 2253, dtype: object

# %%
df_1["salary_min"].astype(int)
df_1["salary_max"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df_1["salary_min"].astype(int)
#       2 df_1["salary_max"].astype(int)
#
# File c:\Users\abaho\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\abaho\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File c:\Users\abaho\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\abaho\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File c:\Users\abaho\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\abaho\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\abaho\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
df_1[df_1["salary_min"] == ""]
# Out:
#       Unnamed: 0                                  Job Title Salary Estimate  \
# 2149        2149  Configuration/Data Management Analyst III              -1
#
#                                         Job Description  Rating  \
# 2149  Job Description\nPosition Title: Configuration...     4.4
#
#          Company Name  Location  Headquarters                 Size  Founded  \
# 2149  Protingent\n4.4  Kent, WA  Bellevue, WA  51 to 200 employees     2001
#
#       Type of ownership                Industry             Sector  \
# 2149  Company - Private  Staffing & Outsourcing  Business Services
#
#                        Revenue Competitors Easy Apply salary_min salary_max
# 2149  $25 to $50 million (USD)          -1         -1                     1

# %%
df_1[df_1["salary_max"] == ""]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Job Title, Salary Estimate, Job Description, Rating, Company Name, Location, Headquarters, Size, Founded, Type of ownership, Industry, Sector, Revenue, Competitors, Easy Apply, salary_min, salary_max]
# Index: []

# %%
bad_row = df_1[df_1["Salary Estimate"] == "-1"].index

# %%
df_1=df_1.drop(bad_row)

# %%
df_1[df_1["Salary Estimate"] == "-1"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Job Title, Salary Estimate, Job Description, Rating, Company Name, Location, Headquarters, Size, Founded, Type of ownership, Industry, Sector, Revenue, Competitors, Easy Apply, salary_min, salary_max]
# Index: []

# %%
df_1["salary_min"]=df_1["salary_min"].astype(int)
df_1["salary_max"]=df_1["salary_max"].astype(int)

# %%
df_1["salary_min"].apply(type)
# Out:
# 0       <class 'int'>
# 1       <class 'int'>
# 2       <class 'int'>
# 3       <class 'int'>
# 4       <class 'int'>
#             ...
# 2248    <class 'int'>
# 2249    <class 'int'>
# 2250    <class 'int'>
# 2251    <class 'int'>
# 2252    <class 'int'>
# Name: salary_min, Length: 2252, dtype: object

# %%
df_1["salary_max"].apply(type)
# Out:
# 0       <class 'int'>
# 1       <class 'int'>
# 2       <class 'int'>
# 3       <class 'int'>
# 4       <class 'int'>
#             ...
# 2248    <class 'int'>
# 2249    <class 'int'>
# 2250    <class 'int'>
# 2251    <class 'int'>
# 2252    <class 'int'>
# Name: salary_max, Length: 2252, dtype: object

# %%
df_1["salary_avg"]=(df_1["salary_min"]+df_1["salary_max"])/2

# %%
df_1[["salary_min", "salary_max", "salary_avg"]].head()
# Out:
#    salary_min  salary_max  salary_avg
# 0          37          66        51.5
# 1          37          66        51.5
# 2          37          66        51.5
# 3          37          66        51.5
# 4          37          66        51.5

# %%
df_1.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'salary_min', 'salary_max', 'salary_avg'],
#       dtype='object')

# %%
col1=df_1.pop("salary_min")
col2=df_1.pop("salary_max")
col3=df_1.pop("salary_avg")
df_1.insert(3,"salary_min",col1)
df_1.insert(4,"salary_max",col2)
df_1.insert(5,"salary_avg",col3)

# %%
df_1.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'salary_min',
#        'salary_max', 'salary_avg', 'Job Description', 'Rating', 'Company Name',
#        'Location', 'Headquarters', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'Competitors', 'Easy Apply'],
#       dtype='object')

# %%
df_test = pd.read_csv("../data/cleaned/data_analyst_set1_cleaned.csv")

df_test.head()
# Out:
#                                            Job Title Salary Estimate  \
# 0  Data Analyst, Center on Immigration and Justic...          37-66
# 1                               Quality Data Analyst          37-66
# 2  Senior Data Analyst, Insights & Analytics Team...          37-66
# 3                                       Data Analyst          37-66
# 4                             Reporting Data Analyst          37-66
#
#    salary_min  salary_max  salary_avg  Rating  \
# 0          37          66        51.5     3.2
# 1          37          66        51.5     3.8
# 2          37          66        51.5     3.4
# 3          37          66        51.5     4.1
# 4          37          66        51.5     3.9
#
#                                 Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\r\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\r\n3.8  New York, NY  New York, NY
# 2                         Squarespace\r\n3.4  New York, NY  New York, NY
# 3                            Celerity\r\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\r\n3.9  New York, NY  New York, NY
#
#                      Size  Founded               Type of ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors  Easy Apply
# 0  $100 to $500 million (USD)          -1           1
# 1      $2 to $5 billion (USD)          -1           0
# 2    Unknown / Non-Applicable     GoDaddy           0
# 3   $50 to $100 million (USD)          -1           0
# 4  $100 to $500 million (USD)  DraftKings           1

# %%
df_test["Size"].value_counts()
# Out:
# Size
# 51 to 200 employees        420
# 10000+ employees           375
# 1001 to 5000 employees     348
# 1 to 50 employees          347
# 201 to 500 employees       249
# 501 to 1000 employees      211
# -1                         163
# 5001 to 10000 employees     97
# Unknown                     42
# Name: count, dtype: int64

# %% [markdown]
# Clean Dataset 1
#
# - Removed unnecessary columns
# - Converted Easy Apply to binary
# - Cleaned Salary Estimate column
# - Created salary_min, salary_max, salary_avg
# - Removed invalid salary record
# - Reordered columns
# - Exported cleaned dataset

# %%
df_2.head(10)
# Out:
#    work_year                    job_title                    job_category  \
# 0       2023         Data DevOps Engineer                Data Engineering
# 1       2023               Data Architect  Data Architecture and Modeling
# 2       2023               Data Architect  Data Architecture and Modeling
# 3       2023               Data Scientist       Data Science and Research
# 4       2023               Data Scientist       Data Science and Research
# 5       2023               Data Scientist       Data Science and Research
# 6       2023               Data Scientist       Data Science and Research
# 7       2023  Machine Learning Researcher         Machine Learning and AI
# 8       2023  Machine Learning Researcher         Machine Learning and AI
# 9       2023                Data Engineer                Data Engineering
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
# 5             USD  130000         130000      United States           Senior
# 6             USD  100000         100000      United States           Senior
# 7             USD  224400         224400      United States        Mid-level
# 8             USD  138700         138700      United States        Mid-level
# 9             USD  210000         210000      United States        Executive
#
#   employment_type work_setting company_location company_size
# 0       Full-time       Hybrid          Germany            L
# 1       Full-time    In-person    United States            M
# 2       Full-time    In-person    United States            M
# 3       Full-time    In-person    United States            M
# 4       Full-time    In-person    United States            M
# 5       Full-time       Remote    United States            M
# 6       Full-time       Remote    United States            M
# 7       Full-time    In-person    United States            M
# 8       Full-time    In-person    United States            M
# 9       Full-time       Remote    United States            M

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
df_2.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %%
print(df_2.shape)
print(df_2.duplicated().sum())
# Out:
# (9355, 12)
# 4014

# %%
df_2["company_size"].value_counts()
# Out:
# company_size
# M    8448
# L     748
# S     159
# Name: count, dtype: int64

# %%
df_2["company_size"] = df_2["company_size"].replace("S","Small")
df_2["company_size"] = df_2["company_size"].replace("M","Medium")
df_2["company_size"] = df_2["company_size"].replace("L","Large")

# %%
df_2["company_size"].value_counts()
# Out:
# company_size
# Medium    8448
# Large      748
# Small      159
# Name: count, dtype: int64

# %%
duplicate_rows = df_2[df_2.duplicated(keep=False)]

duplicate_rows.sort_values(by=["job_title", "salary_in_usd", "employee_residence"]).head(20)
# Out:
#       work_year           job_title               job_category  \
# 3157       2023        AI Architect    Machine Learning and AI
# 3968       2023        AI Architect    Machine Learning and AI
# 4308       2023        AI Architect    Machine Learning and AI
# 4506       2023        AI Architect    Machine Learning and AI
# 3156       2023        AI Architect    Machine Learning and AI
# 3967       2023        AI Architect    Machine Learning and AI
# 4307       2023        AI Architect    Machine Learning and AI
# 4505       2023        AI Architect    Machine Learning and AI
# 1887       2023         AI Engineer    Machine Learning and AI
# 1923       2023         AI Engineer    Machine Learning and AI
# 1886       2023         AI Engineer    Machine Learning and AI
# 1922       2023         AI Engineer    Machine Learning and AI
# 5384       2023  Analytics Engineer  Leadership and Management
# 5703       2023  Analytics Engineer  Leadership and Management
# 8574       2022  Analytics Engineer  Leadership and Management
# 8598       2022  Analytics Engineer  Leadership and Management
# 1504       2023  Analytics Engineer  Leadership and Management
# 5383       2023  Analytics Engineer  Leadership and Management
# 502        2023  Analytics Engineer  Leadership and Management
# 831        2023  Analytics Engineer  Leadership and Management
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 3157             USD  204000         204000      United States
# 3968             USD  204000         204000      United States
# 4308             USD  204000         204000      United States
# 4506             USD  204000         204000      United States
# 3156             USD  330000         330000      United States
# 3967             USD  330000         330000      United States
# 4307             USD  330000         330000      United States
# 4505             USD  330000         330000      United States
# 1887             USD   83900          83900      United States
# 1923             USD   83900          83900      United States
# 1886             USD  170200         170200      United States
# 1922             USD  170200         170200      United States
# 5384             GBP   50000          61520     United Kingdom
# 5703             GBP   50000          61520     United Kingdom
# 8574             USD   63000          63000      United States
# 8598             USD   63000          63000      United States
# 1504             GBP   60000          73824     United Kingdom
# 5383             GBP   60000          73824     United Kingdom
# 502              USD   75000          75000      United States
# 831              USD   75000          75000      United States
#
#      experience_level employment_type work_setting company_location  \
# 3157           Senior       Full-time    In-person    United States
# 3968           Senior       Full-time    In-person    United States
# 4308           Senior       Full-time    In-person    United States
# 4506           Senior       Full-time    In-person    United States
# 3156           Senior       Full-time    In-person    United States
# 3967           Senior       Full-time    In-person    United States
# 4307           Senior       Full-time    In-person    United States
# 4505           Senior       Full-time    In-person    United States
# 1887           Senior       Full-time    In-person    United States
# 1923           Senior       Full-time    In-person    United States
# 1886           Senior       Full-time    In-person    United States
# 1922           Senior       Full-time    In-person    United States
# 5384        Mid-level       Full-time    In-person   United Kingdom
# 5703        Mid-level       Full-time    In-person   United Kingdom
# 8574           Senior       Full-time    In-person    United States
# 8598           Senior       Full-time    In-person    United States
# 1504        Mid-level       Full-time    In-person   United Kingdom
# 5383        Mid-level       Full-time    In-person   United Kingdom
# 502         Mid-level       Full-time    In-person    United States
# 831         Mid-level       Full-time    In-person    United States
#
#      company_size
# 3157       Medium
# 3968       Medium
# 4308       Medium
# 4506       Medium
# 3156       Medium
# 3967       Medium
# 4307       Medium
# 4505       Medium
# 1887       Medium
# 1923       Medium
# 1886       Medium
# 1922       Medium
# 5384       Medium
# 5703       Medium
# 8574       Medium
# 8598       Medium
# 1504       Medium
# 5383       Medium
# 502        Medium
# 831        Medium

# %%
df_2.drop_duplicates().shape
# Out:
# (5341, 12)

# %%
df_2.nunique()
# Out:
# work_year                4
# job_title              125
# job_category            10
# salary_currency         11
# salary                1507
# salary_in_usd         1786
# employee_residence      83
# experience_level         4
# employment_type          4
# work_setting             3
# company_location        70
# company_size             3
# dtype: int64

# %% [markdown]
# ## Dataset 2 Cleaning Summary
#
# ### Changes Made
#
# - Converted `company_size` values into descriptive labels:
#   - `S` → `Small`
#   - `M` → `Medium`
#   - `L` → `Large`
#
# ### Data Quality Checks
#
# - Checked for missing values.
# - Checked for duplicate records.
# - Found 4,014 duplicate rows.
#
# ### Duplicate Decision
#
# The duplicate rows were **not removed**.
#
# Reason:
# This dataset does not contain a unique employee ID or company ID. Because of that, multiple employees may legitimately share the same values (job title, salary, country, experience level, etc.). Removing duplicates could accidentally delete valid records.
#
# ### Result
#
# The dataset required very little cleaning compared to Dataset 1 and was already well structured.

# %%
df_3.head(10)
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT             Data Architect
# 1       2024               SE              FT             Data Architect
# 2       2024               MI              FT            Insight Analyst
# 3       2024               MI              FT            Insight Analyst
# 4       2024               SE              FT              Lead Engineer
# 5       2024               SE              FT              Lead Engineer
# 6       2024               SE              FT  Machine Learning Engineer
# 7       2024               SE              FT  Machine Learning Engineer
# 8       2024               SE              FT  Machine Learning Engineer
# 9       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  170955             USD         170955                 US             0
# 1  130270             USD         130270                 US             0
# 2   92144             USD          92144                 US           100
# 3   57616             USD          57616                 US           100
# 4  201600             USD         201600                 US           100
# 5  181440             USD         181440                 US           100
# 6  296300             USD         296300                 US             0
# 7  166600             USD         166600                 US             0
# 8  264200             USD         264200                 US             0
# 9  143100             USD         143100                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            M
# 4               US            M
# 5               US            M
# 6               US            M
# 7               US            M
# 8               US            M
# 9               US            M

# %%
print(df_3["experience_level"].value_counts())
print("--------------------")
print(df_3["employment_type"].value_counts())
print("-------------------------")
print(df_3["company_size"].value_counts())
# Out:
# experience_level
# SE    24236
# MI    11731
# EN     3477
# EX      888
# Name: count, dtype: int64
# --------------------
# employment_type
# FT    40203
# PT       60
# CT       55
# FL       14
# Name: count, dtype: int64
# -------------------------
# company_size
# M    38611
# L     1521
# S      200
# Name: count, dtype: int64

# %%
df_3["experience_level"] = df_3["experience_level"].replace("SE","Senior level")
df_3["experience_level"] = df_3["experience_level"].replace("MI","Mid level")
df_3["experience_level"] = df_3["experience_level"].replace("EN","Entry level")
df_3["experience_level"] = df_3["experience_level"].replace("EX","Executive level")

# %%
df_3["employment_type"] = df_3["employment_type"].replace("FT","Full time")
df_3["employment_type"] = df_3["employment_type"].replace("PT","Part-time")
df_3["employment_type"] = df_3["employment_type"].replace("CT","Contract")
df_3["employment_type"] = df_3["employment_type"].replace("FL","Freelance")

# %%
df_3["company_size"] = df_3["company_size"].replace("L","Large")
df_3["company_size"] = df_3["company_size"].replace("M","Medium")
df_3["company_size"] = df_3["company_size"].replace("S","Small")

# %%
df_3.head(10)
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024     Senior level       Full time             Data Architect
# 1       2024     Senior level       Full time             Data Architect
# 2       2024        Mid level       Full time            Insight Analyst
# 3       2024        Mid level       Full time            Insight Analyst
# 4       2024     Senior level       Full time              Lead Engineer
# 5       2024     Senior level       Full time              Lead Engineer
# 6       2024     Senior level       Full time  Machine Learning Engineer
# 7       2024     Senior level       Full time  Machine Learning Engineer
# 8       2024     Senior level       Full time  Machine Learning Engineer
# 9       2024     Senior level       Full time  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  170955             USD         170955                 US             0
# 1  130270             USD         130270                 US             0
# 2   92144             USD          92144                 US           100
# 3   57616             USD          57616                 US           100
# 4  201600             USD         201600                 US           100
# 5  181440             USD         181440                 US           100
# 6  296300             USD         296300                 US             0
# 7  166600             USD         166600                 US             0
# 8  264200             USD         264200                 US             0
# 9  143100             USD         143100                 US             0
#
#   company_location company_size
# 0               US       Medium
# 1               US       Medium
# 2               US       Medium
# 3               US       Medium
# 4               US       Medium
# 5               US       Medium
# 6               US       Medium
# 7               US       Medium
# 8               US       Medium
# 9               US       Medium

# %% [markdown]
# # Dataset 3 Cleaning Summary
#
# ## Changes Made
#
# ### experience_level
#
# Converted abbreviated experience levels into descriptive values.
#
# - EN → Entry level
# - MI → Mid level
# - SE → Senior level
# - EX → Executive level
#
# ---
#
# ### employment_type
#
# Converted abbreviated employment types into descriptive values.
#
# - FT → Full time
# - PT → Part-time
# - CT → Contract
# - FL → Freelance
#
# ---
#
# ### company_size
#
# Converted abbreviated company size values into descriptive labels.
#
# - S → Small
# - M → Medium
# - L → Large
#
# ---
#
# ### remote_ratio
#
# The `remote_ratio` column was left unchanged.
#
# Reason:
#
# The values already represent meaningful numeric categories.
#
# - 0 = On-site
# - 50 = Hybrid
# - 100 = Fully remote
#
# Keeping the column numeric makes it easier to analyze in SQL and Power BI while preserving the ordinal relationship between work settings.
#
# ---
#
# ## Data Quality Checks
#
# - Checked missing values.
# - Checked duplicate rows.
# - Reviewed categorical columns.
# - Verified data types.
#
# No additional cleaning was required.
#
# ---
#
# ## Result
#
# Dataset 3 was already well structured. The primary cleaning task was improving readability by replacing abbreviated categorical values with descriptive labels while preserving the original meaning of the data.

# %%
df_2["work_setting"].head(20)
# Out:
# 0        Hybrid
# 1     In-person
# 2     In-person
# 3     In-person
# 4     In-person
# 5        Remote
# 6        Remote
# 7     In-person
# 8     In-person
# 9        Remote
# 10       Remote
# 11    In-person
# 12    In-person
# 13    In-person
# 14    In-person
# 15    In-person
# 16    In-person
# 17    In-person
# 18    In-person
# 19    In-person
# Name: work_setting, dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
print("Libraries imported successfully!")

#Get the data
df_1=pd.read_csv("../data/raw/DataAnalyst_set1_raw.csv")
df_2=pd.read_csv("../data/raw/jobs_in_data_set2_raw.csv")
df_3=pd.read_csv("../data/raw/global_ai_ml_data_salaries_set3_raw.csv")

#Start cleaning the first dataset
df_1.drop(columns=["Unnamed: 0"], inplace=True)
df_1.drop(columns=["Job Description"],inplace=True)

#changing the values of Easy Apply to 0's and 1's so its easyer to use in mysql
df_1["Easy Apply"]=df_1["Easy Apply"].replace({"True": 1 , "-1": 0})

#cleaning Salary Estimate and convirting it to three colums
df_1["Salary Estimate"] = df_1["Salary Estimate"].str.replace("(Glassdoor est.)","")
df_1["Salary Estimate"]=df_1["Salary Estimate"].str.replace("$","")
df_1["Salary Estimate"] =df_1["Salary Estimate"] .str.replace("K","")

#creat salary_min and salary_max out of Salary Estimate
df_1[["salary_min","salary_max"]] = df_1["Salary Estimate"].str.split("-",expand=True) 

#Deleting the row with the missing value so I could change the data type of both salary_min and salary_max
bad_row = df_1[df_1["Salary Estimate"] == "-1"].index
df_1=df_1.drop(bad_row)

#changing the data type
df_1["salary_min"]=df_1["salary_min"].astype(int)
df_1["salary_max"]=df_1["salary_max"].astype(int)

#Creat salary_avg
df_1["salary_avg"]=(df_1["salary_min"]+df_1["salary_max"])/2
print("------------------------------------------")
#print(df_1.columns)
# change the place of the colums
col1=df_1.pop("salary_min")
col2=df_1.pop("salary_max")
col3=df_1.pop("salary_avg")
df_1.insert(2,"salary_min",col1)
df_1.insert(3,"salary_max",col2)
df_1.insert(4,"salary_avg",col3)
#print(df_1.columns)

df_1.to_csv("../data/cleaned/data_analyst_set1_cleaned.csv",index=False)

#Data-set-2

#Converted company_size codes (S/M/L) to Small/Medium/Large.
df_2["company_size"] = df_2["company_size"].replace("S","Small")
df_2["company_size"] = df_2["company_size"].replace("M","Medium")
df_2["company_size"] = df_2["company_size"].replace("L","Large")

df_2.to_csv("../data/cleaned/jobs_in_data_set2_cleaned.csv",index=False)

#Data-set-3

#Expanded experience level abbreviations.
df_3["experience_level"] = df_3["experience_level"].replace("SE","Senior level")
df_3["experience_level"] = df_3["experience_level"].replace("MI","Mid level")
df_3["experience_level"] = df_3["experience_level"].replace("EN","Entry level")
df_3["experience_level"] = df_3["experience_level"].replace("EX","Executive level")

#Expanded employment type abbreviations.
df_3["employment_type"] = df_3["employment_type"].replace("FT","Full time")
df_3["employment_type"] = df_3["employment_type"].replace("PT","Part-time")
df_3["employment_type"] = df_3["employment_type"].replace("CT","Contract")
df_3["employment_type"] = df_3["employment_type"].replace("FL","Freelance")

#Expanded company size abbreviations.
df_3["company_size"] = df_3["company_size"].replace("L","Large")
df_3["company_size"] = df_3["company_size"].replace("M","Medium")
df_3["company_size"] = df_3["company_size"].replace("S","Small")

df_3.to_csv("../data/cleaned/global_ai_ml_data_salaries_set3_cleaned.csv",index=False)

#preparation to combine the three data sets

set1 = df_1.copy()
set2 = df_2.copy()
set3 = df_3.copy()

set1["company_size_standardized"] = set1["Size"].replace({
    "1 to 50 employees": "Small",
    "51 to 200 employees": "Medium",
    "201 to 500 employees": "Large",
    "501 to 1000 employees": "Large",
    "1001 to 5000 employees": "Large",
    "5001 to 10000 employees": "Large",
    "10000+ employees": "Large",
    "-1": "Unknown"
})

set1_standardized = pd.DataFrame({
    "work_year" : pd.NA,
    "job_title" : set1["Job Title"],
    "job_category" : pd.NA,
    "salary_currency" : "USA",
    "salary" : set1["salary_avg"]*1000,
    "salary_in_usd" : set1["salary_avg"]*1000,
    "employee_residence" : pd.NA,
    "experience_level" : pd.NA,
    "employment_type" : pd.NA,
    "remote_ratio" : pd.NA,
    "company_location" : set1["Location"],
    "company_size" : set1["company_size_standardized"],
    "data_source" : "Glassdoor Data Analyst Jobs"
})

set2["remote_ratio"] = set2["work_setting"].map({
    "In-person": 0,
    "Hybrid": 50,
    "Remote": 100
})

set2_standardized = pd.DataFrame({
    "work_year" : set2["work_year"],
    "job_title" : set2["job_title"],
    "job_category" : set2["job_category"],
    "salary_currency" : set2["salary_currency"],
    "salary" : set2["salary"],
    "salary_in_usd" : set2["salary_in_usd"],
    "employee_residence" : set2["employee_residence"],
    "experience_level" : set2["experience_level"],
    "employment_type" : set2["employment_type"],
    "work_setting" : set2["work_setting"],
    "company_location" : set2["company_location"],
    "company_size" : set2["company_size"],
    "data_source": "Jobs in Data"
})

set3["experience_level"] = set3["experience_level"].replace({
    "Entry level": "Entry-level",
    "Mid level": "Mid-level",
    "Senior level": "Senior",
    "Executive level": "Executive"
})

set3["employment_type"] = set3["employment_type"].replace({
    "Full time": "Full-time",
    "Part-time": "Part-time",
    "Contract": "Contract",
    "Freelance": "Freelance"
})

set3_standardized = pd.DataFrame({
    "work_year": set3["work_year"],
    "job_title": set3["job_title"],
    "job_category": pd.NA,
    "salary_currency": set3["salary_currency"],
    "salary": set3["salary"],
    "salary_in_usd": set3["salary_in_usd"],
    "employee_residence": set3["employee_residence"],
    "experience_level": set3["experience_level"],
    "employment_type": set3["employment_type"],
    "remote_ratio": set3["remote_ratio"],
    "company_location": set3["company_location"],
    "company_size": set3["company_size"],
    "data_source": "Global AI/ML Salaries"
})


combined_salary_data = pd.concat([
    set1_standardized,
    set2_standardized,
    set3_standardized

], ignore_index=True)
combined_salary_data = pd.concat([
    set1_standardized,
    set2_standardized,
    set3_standardized

], ignore_index=True)

#combined_salary_data["job_title"].combine_first(combined_salary_data["job_title"])

combined_salary_data.rename(
    columns={"salary": "salary_local"},
    inplace=True
)

combined_salary_data["work_setting_standardized"] = combined_salary_data["remote_ratio"].replace({
    0: "In-person",
    50: "Hybrid",
    100: "Remote"
})

combined_salary_data["work_setting_standardized"]= (
    combined_salary_data["work_setting_standardized"].
    combine_first(combined_salary_data["work_setting"]))

combined_salary_data.drop(columns=["work_setting"], inplace=True)

#print(combined_salary_data.shape)
print("----------------------------")
#print(combined_salary_data.isnull().sum())
print("----------------------------")
#print(combined_salary_data["data_source"].value_counts())
print("---------------------")
#print(combined_salary_data["salary_in_usd"].describe())
print("-----------------------------")
#print(combined_salary_data.columns.tolist())
print("------------------------------------------")
print(combined_salary_data.dtypes)
# Out:
# Libraries imported successfully!
# C:\Users\abaho\AppData\Local\Temp\ipykernel_24332\1715515657.py:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_1["Easy Apply"]=df_1["Easy Apply"].replace({"True": 1 , "-1": 0})
# ------------------------------------------
# ----------------------------
# ----------------------------
# ---------------------
# -----------------------------
# ------------------------------------------
# work_year                     object
# job_title                     object
# job_category                  object
# salary_currency               object
# salary_local                 float64
# salary_in_usd                float64
# employee_residence            object
# experience_level              object
# employment_type               object
# remote_ratio                 float64
# company_location              object
# company_size                  object
# data_source                   object
# work_setting_standardized     object
# dtype: object
# C:\Users\abaho\AppData\Local\Temp\ipykernel_24332\1715515657.py:167: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_salary_data = pd.concat([
# C:\Users\abaho\AppData\Local\Temp\ipykernel_24332\1715515657.py:173: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_salary_data = pd.concat([

# %%
print(combined_salary_data.head())
print(combined_salary_data.columns)
# Out:
#   work_year                                          job_title job_category  \
# 0      <NA>  Data Analyst, Center on Immigration and Justic...         <NA>
# 1      <NA>                               Quality Data Analyst         <NA>
# 2      <NA>  Senior Data Analyst, Insights & Analytics Team...         <NA>
# 3      <NA>                                       Data Analyst         <NA>
# 4      <NA>                             Reporting Data Analyst         <NA>
#
#   salary_currency  salary_local  salary_in_usd employee_residence  \
# 0             USA       51500.0        51500.0                NaN
# 1             USA       51500.0        51500.0                NaN
# 2             USA       51500.0        51500.0                NaN
# 3             USA       51500.0        51500.0                NaN
# 4             USA       51500.0        51500.0                NaN
#
#   experience_level employment_type  remote_ratio company_location  \
# 0              NaN             NaN           NaN     New York, NY
# 1              NaN             NaN           NaN     New York, NY
# 2              NaN             NaN           NaN     New York, NY
# 3              NaN             NaN           NaN     New York, NY
# 4              NaN             NaN           NaN     New York, NY
#
#   company_size                  data_source work_setting_standardized
# 0        Large  Glassdoor Data Analyst Jobs                       NaN
# 1        Large  Glassdoor Data Analyst Jobs                       NaN
# 2        Large  Glassdoor Data Analyst Jobs                       NaN
# 3        Large  Glassdoor Data Analyst Jobs                       NaN
# 4        Large  Glassdoor Data Analyst Jobs                       NaN
# Index(['work_year', 'job_title', 'job_category', 'salary_currency',
#        'salary_local', 'salary_in_usd', 'employee_residence',
#        'experience_level', 'employment_type', 'remote_ratio',
#        'company_location', 'company_size', 'data_source',
#        'work_setting_standardized'],
#       dtype='object')
